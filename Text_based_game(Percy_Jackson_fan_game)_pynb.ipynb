# %%
# Text based adventure game
#global imports
import time, sys, os

def typewriter(message):
  for char in message:
    sys.stdout.write(char)
    sys.stdout.flush()
    time.sleep(0.1)
  print("\n")



typewriter("This is a Percy Jackson fan game.")
name = input("what is your name? ")

def introDisplay():
  print("\nHello there, " + name )
  typewriter("You are on an adventure in Egypt with your friend Jack Kane an archeologist. He insisted on this adventure in Egypt. But you dont like it.\n")

introDisplay()


# adventure start
typewriter("You have been on this so called 'adventure' for the past 1 hour but you are already thirsty and there is no water.")

typewriter("You look at your friend even he is starting to regret beign here.")

typewriter("As you climb the peak of a dune. You see something!!")

typewriter("Not an oasis but a woman with a cat head.Your friends eyes widen and he faints.As he faints he says 'Bastet pls help us' ")
typewriter("You assume that the womans name is 'Bastet'")
print("\n")

def choosePath():
  option = ""
  while option != "1" and option != "2":
    bastet = input("Do you run away(Option '1')  or   go to the cat-headed person for help (Option '2'): ")
    if bastet == "1" or bastet == "2":
      return bastet
      break

f = choosePath()

if f == "1":
  typewriter("You died of thirst \nGAME OVER")
else:
  typewriter("You walked towards her dragging Jack by your side and asked for help.")
  typewriter("The woman smiled and waved a hand over your face which made you blackout.")

  typewriter("You woke up and saw you were in a house, outside the window there were other houses.")

  typewriter("You get up and see your friend is sitting with the woman for breakfast.")
  print("\n")


  def choosePath1():
    option1 = ""
    while option1 != "1" and option1 != "2":
      breakfast = input("Do you run away leaving your friend(Option '1')  or  go to them(Option '2'): ")
      if breakfast == "1" or breakfast == "2":
        return breakfast
        break
  f = choosePath1()
  if f == "1":
    typewriter("You ran outside the house and stumbled into a portal which led you to your house")
    typewriter("You betrayed your friend 😡 \n\n GAME OVER")
  else:
    typewriter("Your friend greeted you as you sat down.")
    typewriter("He explained that the the Egyptian gods were alive!!🤯")
    typewriter("and this woman was Bastet goddess of protection, cats etc.")
    typewriter("Bastet: 'you can call me Bast' 😺")
    typewriter("Jack: 'This is amazing😃' ")
    typewriter("Jack: Bast says we must leave Egypt immediately😞 \n")
    typewriter("Bast: yes these lands are very dangerous, Apopphis a.k.a. The enemy of light is growing stronger ")
    typewriter(" Even I can help only to an extent, even my powers are weakening 😿")
    typewriter("You hold her hand and you teleport")
    time.sleep(3)
    typewriter("You are in the middle of a desert")
    typewriter("on the horizon you see an ocean")
    typewriter("Bast: You must flee, take this sword it is a khopesh and take this bow and arrow")
    typewriter("You are travelling.....")
    time.sleep(30)
    typewriter("Now you see a boat..")
    typewriter("on the horizon you see land")

  def choosePath2():
    option1 = ""
    while option1 != "1" and option1 != "2":
      boat = input("Do you want to sit in the boat (option '1') or swim across (option'2')")
      if boat == "1" or boat == "2":
        return boat
        break
  f = choosePath2()
  if f == "2":
    typewriter("You tried to swim across, a shark 🦈 ate you.")
    typewriter("GAME OVER")
  else:
    typewriter("You notice that the boat started moving on it's own as you sat. ")
    typewriter("rowing ..............")
    time.sleep(10)
    typewriter("🔥SECOND CHAPTER🔥")
    typewriter("You are starving")
    typewriter("You reached a beach and you see a local. ")
    typewriter("Jack: I think we must ask that local where we are cuz I dont see anyone else.")
  def choosePath3():
    option1 = ""
    while option1 != "1" and option1 != "2":
      local = input("Do you want to ask the local where you are? (option '1') or steer clear from him? (option'2')")
      if local == "1" or local == "2":
        return local
        break   
  f = choosePath3()
  if f == "2":
    typewriter("You starve to death 😵 \nGAME OVER")
  else:
    typewriter("Local: You are in Greece, Tourists dont usually come here🤨, Are you a demi-god?")
    typewriter("Jack: No!! Why would you think so?")
    typewriter("You have goat legs!!! Are you a saytr?😦")
    typewriter("You also notice his legs")
    typewriter("Local: You can see them!!? You say you are not a demi-god...you can see through the mist!! ")
    typewriter("Jack so saytr's are true!!?")
    typewriter("Local: Yes, I must take you to your home.I know a safe house, but it is across The Jungle of Térata! \nWhere do you live? ")
    typewriter("Jack: We live in New York.")
    time.sleep(4)
    typewriter(" 🔥 THIRD CHAPTER 🔥")
    typewriter("The Jungle of Térata")
    typewriter("You enter the jungle!")
    typewriter("Its dark as the treetops are very thick... ")
    time.sleep(3)
    typewriter("You hear a howl...")
    typewriter("The Saytr: Hellhound!!, its a big killer bear")
    typewriter("Jack: We cannot outrun it so we must fight it, I do know some greek mythology.")
  def choosePath4():
    option1 = ""
    while option1 != "1" and option1 != "2":
      hound = input("Do you want to use your bow? (option '1') or  your khopesh? (option'2')")
      if hound == "1" or hound == "2":
        return hound
        break   
  f = choosePath4()
  if f == "1":
    typewriter("You shot arrows, but they did not affect the hellhound")
    typewriter("It ate you \nGAME OVER")
  else:
    typewriter("As soon as you removed the sword you felt a surge of power!!")
    typewriter("You lunged and slashed at the monster. ")
    typewriter("After killing the monster..\n")
    typewriter("Saytr: A eagle was fighting with you!!🤯")
    typewriter("Jack: That was the sacred animal of Horus an Egyptian god!")
    typewriter("Saytr: So Egyptian gods exist!")
    typewriter("Jack: Yeah we met one in Egypt, long story ")
    typewriter("'Hello there!' somebody says in front of you.")
    typewriter("He looks like teenager around 17-18, but your gut tells you to back-off ")
    typewriter("Oh I am Lityerses a.k.a.'reaper of men' you can call me Lit for short 😉 ")
    typewriter("Saytr: Nice to meet you...Lit😥. But we better get going.")
    typewriter("Lit: Oh but I have not even started yet")
    typewriter("Jack: "+ name + " we must run!! ")
  def choosePath5():
    option1 = ""
    while option1 != "1" and option1 != "2":
      lit = input("Do you want to fight? (option '1')  or run (option'2')")
      if lit == "1" or lit == "2":
        return lit
        break     
  f = choosePath5()
  if f == "2":
    typewriter("You tried to run, but Lit killed you \nGAME OVER")
  else:
    typewriter("you: I am going to fight, You give your bow to Jack and you use khopesh")
    typewriter("Oh 2 versus 1, I dont care cuz ppl dont call me reaper of men for nothing.")
    typewriter("As soon as you start fighting Lit attacks and says 'I will go easy on you'")
    typewriter("You dont get a chance to attack.....parry, parry....")
    typewriter("You are disarmed and your friends bow is broken.")
    typewriter("Suddenly a mighty eagle swoops down and disarms Lit")
    typewriter("Jack: Yeah!!!")
    typewriter("Lit: im-impossible, wa-wa-what is this?😧")
    typewriter("You feel a sudden surge of power..SLASH! you killed Lit as you kill him he turns into dust.")
    typewriter("You realise the saytr was horror struck the whole time.")
    typewriter("saytr: THAT, was close!!")
    typewriter("saytr: We have reached the safe house!😌 ")
    typewriter("You reach the safe house, you eat, then you sleep with extreme exhaustion 💤")
    typewriter("When you wake up you see a boy, Jack and the saytr was talking together")
    typewriter("Your friend notices that you woke up he says-")
    typewriter("Jack: Hey" + name )
    typewriter("Jack:(pointing at the boy)This is Alex he is a Demigod!")
    typewriter("Alex: Wassup " + name +" and yes I am a demigod." )
    typewriter("Alex: I am here to help to reach you to your home, Your friend told me you are a good fighter...")
    typewriter("Alex: I am a son of Hecate, suddenly he turned into a wolf and back human again")
    typewriter("Jack: hecate is the greek goddess of magic, illusions etc. In short shocking 😧")
    typewriter("Lets go!!(everyone in unision!)")
    typewriter("You are teleporting.....")
    time.sleep(5)
    typewriter("woah! You reach 'Kato Alepochori' (coast of Greece)")
    typewriter("Its a beach full of rocks...")
    typewriter("🔥Sciron- The Robber🔥")
    typewriter("To be continued in version2")
